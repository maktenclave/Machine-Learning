# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from scipy import stats
df = pd.read_excel("Weight of copper dataset.xlsx")
df.head(4)
# Out:
#    Unnamed: 0  power_rating  weight_of_copper category
# 0           0         16.46             34.69     high
# 1           1         12.52             28.78     high
# 2           2          7.66             21.48     high
# 3           3         21.09             41.64     high

# %%
#df_reduced = df[["power_rating", "weight_of_copper"]].rolling(100).mean().dropna()
#x = df_reduced["power_rating"].values
#y = df_reduced["weight_of_copper"].values
#y = df_reduced
x = df["power_rating"]
y = df["weight_of_copper"]
x = np.array(x)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.33,random_state = 42)
slope, intercept, r, p, std_err = stats.linregress(x_train, y_train)
plt.scatter(x,y)
def myfunc(x):
    return (slope * x) + intercept

mymodel = list(map(myfunc,x))
plt.scatter(x,y)
plt.plot(x, mymodel)
plt.show()

# %%
x = x.reshape(-1,1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train, y_train.values.ravel())
y_pred = clf.predict(x_test)
y_pred
# Out:
# array([58.2699376 , 79.20993007, 32.27494694, 18.36995194, 25.47994939,
#        31.17994734, 71.48493284, 32.63494681, 42.48994327, 76.70493097,
#        82.67492882, 25.28494946, 35.37994583, 42.3999433 , 63.89493557,
#        52.85493954, 59.22993725, 72.11493262, 55.41993862, 62.46993609,
#        63.03993588, 27.53494865, 30.54994756, 79.22493006, 43.71994283,
#        31.73494714, 69.26493364, 36.71494535, 35.70994571, 66.12993477,
#        67.55493426, 36.93994527, 59.15493728, 59.42493718, 21.48995082,
#        32.28994694, 37.17994518, 48.57994108, 36.32494549, 24.12994987,
#        38.13994483, 24.21994984, 44.78494244, 53.5299393 , 50.22994049,
#        33.05494666, 34.68994608, 46.35994188, 64.44993537, 45.7449421 ,
#        69.44493358, 22.89995031, 51.54994001, 18.53495188, 38.25994479,
#        79.80992985, 78.02493049, 33.68494644, 70.97493303, 81.29492932,
#        71.79993273, 41.12494376, 62.61993603, 50.66494033, 80.19992971,
# ...

# %%
print("Intercept:",intercept)
print("Slope:",slope)
# Out:
# Intercept: 9.999954953675648
# Slope: 1.4999994605925824

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
print("r2_score:",r2_score(y_test,y_pred))
# Out:
# r2_score: 0.9999999101939253

# %%
new_year=[[2023]]
x=clf.predict(new_year)
x
# Out:
# array([3044.49886373])

# %%
new_year=[[2025]]
x=clf.predict(new_year)
print(x)
# Out:
# [3047.49886265]
